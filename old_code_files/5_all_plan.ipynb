# %% [markdown]
# ## Things to do and interactions

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_parquet("/Users/aniket/TU_Eindhoven/2_Study/Q4_2AMV10_Visual_Analytics/4_Code/2_AMV10_Visual_Analytics/processed_data/movies_data_updated.parquet")

# %%
df
# Out:
#        movieId   imdbId  tmdbId    imdb_id                              title  \
# 0            1   114709     862  tt0114709                          Toy Story
# 1            2   113497    8844  tt0113497                            Jumanji
# 2            3   113228   15602  tt0113228                   Grumpier Old Men
# 3            4   114885   31357  tt0114885                  Waiting to Exhale
# 4            5   113041   11862  tt0113041        Father of the Bride Part II
# ...        ...      ...     ...        ...                                ...
# 46893   181393  1684935   79782  tt1684935                             Venice
# 46894   181751   169102   19666  tt0169102  Lagaan: Once Upon a Time in India
# 46895   183123   288243   97206  tt0288243                              Taboo
# 46896   187127  1691152  413765  tt1691152          David Lynch: The Art Life
# 46897   191775   211946   30508  tt0211946                     Berlin Calling
#
# ...
