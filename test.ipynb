# %%
import pandas as pd
from common_functions import *

# %%
df = pd.read_parquet("processed_data/movies_data_updated.parquet")

# %%
df.head()
# Out:
#    movieId  imdbId  tmdbId    imdb_id                        title  \
# 0        1  114709     862  tt0114709                    Toy Story
# 1        2  113497    8844  tt0113497                      Jumanji
# 2        3  113228   15602  tt0113228             Grumpier Old Men
# 3        4  114885   31357  tt0114885            Waiting to Exhale
# 4        5  113041   11862  tt0113041  Father of the Bride Part II
#
#   original_language                                           overview  \
# 0                en  Led by Woody, Andy's toys live happily in his ...
# 1                en  When siblings Judy and Peter discover an encha...
# 2                en  A family wedding reignites the ancient feud be...
# 3                en  Cheated on, mistreated and stepped on, the wom...
# 4                en  Just when George Banks has recovered from his ...
#
#                                              tagline release_date  \
# ...

# %%
df['release_year'].min(), df['release_year'].max()
# Out:
# (1874.0, 2020.0)

# %%
get_column(df, 'release_year')
# Out:
# array([1995., 1995., 1995., ..., 2002., 2017., 2008.])

# %%
get_column_min_max(df, 'release_year')
# Out:
# {'min_value': 1874.0, 'max_value': 2020.0}

# %%
list(df.columns.values)
# Out:
# ['movieId',
#  'imdbId',
#  'tmdbId',
#  'imdb_id',
#  'title',
#  'original_language',
#  'overview',
#  'tagline',
#  'release_date',
#  'release_year',
#  'release_month',
#  'release_decade',
#  'movie_age',
#  'is_recent',
#  'runtime',
#  'runtime_bin',
#  'is_short_film',
#  'is_feature_film',
#  'is_long_film',
#  'status',
#  'adult',
#  'homepage',
#  'poster_url',
#  'collection_name',
#  'budget',
#  'revenue',
#  'profit',
#  'roi',
#  'log_budget',
#  'log_revenue',
#  'log_profit',
#  'vote_average',
#  'vote_count',
#  'vote_min',
#  'vote_max',
#  'popularity',
#  'popularity_score',
#  'critical_success',
#  'crowd_approval',
#  'genre_list',
#  'main_genre',
#  'genre_count',
#  'keywords',
#  'keyword_count',
#  'tag',
#  'tag_count',
#  'director',
#  'director_popularity',
#  'producer',
#  'producer_popularity',
#  'lead_actor',
#  'lead_actor_popularity',
#  'lead_actor_genre_diversity',
#  'other_lead',
#  'other_lead_popularity',
# ...

# %%
get_column(df, 'director').unique().shape
# Out:
# (46898,)
